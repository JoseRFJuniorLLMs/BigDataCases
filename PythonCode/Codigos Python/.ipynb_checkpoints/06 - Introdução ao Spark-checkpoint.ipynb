# %% [markdown]
# ![header.png](attachment:header.png)
# # Universidade dos Dados
# GitHub: http://www.github.com/unidados/
#
# Site de dicas: https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/

# %% [markdown]
# # Criação de Contexto

# %% [markdown]
# Sc é uma conexão com o Spark Cluster e é criado no momento da execução do comando PySpark.
# Estamos no Python, portanto, temos que nos conectar ao cluster Spark.

# %%
#Contexto criado automaticamente

# %%
print(sc)

# %%
print(sc.version)

# %%
#Criando o contexto importando o SparkContext

from pyspark import SparkContext

# %%
sc = SparkContext.getOrCreate()

# %%
print(sc)

# %% [markdown]
# # Criando o contexto com opções

# %%
#Rodar em arquivos py

from pyspark import SparkContext
sc = SparkContext(master="local", appName="Aplicacao")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f369b43a3853> in <module>()
#       2
#       3 from pyspark import SparkContext
# ----> 4 sc = SparkContext(master="local", appName="Aplicacao")
#
# C:\Spark\python\pyspark\context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     113         """
#     114         self._callsite = first_spark_call() or CallSite(None, None, None)
# --> 115         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     116         try:
#     117             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# C:\Spark\python\pyspark\context.py in _ensure_initialized(cls, instance, gateway, conf)
#     297                         " created by %s at %s:%s "
#     298                         % (currentAppName, currentMaster,
# --> 299                             callsite.function, callsite.file, callsite.linenum))
#     300                 else:
#     301                     SparkContext._active_spark_context = instance
#
# ValueError: Cannot run multiple SparkContexts at once; existing SparkContext(app=PySparkShell, master=local[*]) created by <module> at C:\Users\Mafra\Anaconda3\lib\site-packages\IPython\utils\py3compat.py:186

# %% [markdown]
# # Contexto SQL

# %% [markdown]
# Permite processamento de arquivos JSON e integra-se com o Hive. Permite também a consulta no estilo SQL utilizando JDBC

# %%
print(sqlContext)

# %% [markdown]
# # Leitura de Dados

# %%
#Criando RDDs através de dados

dados_nativos = sc.parallelize([('Brasil',5),('Alemanha',4),('Italia',4),('Argentina',2)])

# %%
#Criando RDDs através de arquivos

path = 'C:\\Spark\\projetos\\datasets\\airlines.csv'

dados_arquivo = sc.textFile(path)

# %%
#Leitura do HDFS Hadoop

dados_hdfs = "hdfs:///user/diretorio1/diretorio2/arquivo.csv"

# %% [markdown]
# # Verificando a Tipagem

# %%
type(dados_nativos)

# %%
type(dados_arquivo)

# %% [markdown]
# # RDDs?

# %% [markdown]
# ![RDDs.PNG](attachment:RDDs.PNG)

# %%
#Simulando um Cluster Local
#O ideal é que o número seja igual ao número de CORE's do seu computador

pyspark --master local[2]

# %% [markdown]
# ![Processors.PNG](attachment:Processors.PNG)

# %% [markdown]
# # Imprimindo os Dados

# %%
dados_nativos

# %%
#Observe que estamos paralelizando em threads

dados_arquivo

# %%
dados_nativos.collect()

# %%
dados_arquivo.take(10)

# %% [markdown]
# Operações com RDD's na próxima aula!
